# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsGreyedOut/Deep-Learning-Charity-Funding-Predictor/blob/main/AlphabetSoupCharity_Optimzation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
url = 'https://raw.githubusercontent.com/ItsGreyedOut/Deep-Learning-Charity-Funding-Predictor/main/Resources/charity_data.csv'

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv(url)
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(columns = ['EIN'])

# %%
# Determine the number of unique values in each column.
for x in application_df.columns:
    print(x, len(application_df[x].unique()))
# Out:
# NAME 19568
# APPLICATION_TYPE 17
# AFFILIATION 6
# CLASSIFICATION 71
# USE_CASE 5
# ORGANIZATION 4
# STATUS 2
# INCOME_AMT 9
# SPECIAL_CONSIDERATIONS 2
# ASK_AMT 8747
# IS_SUCCESSFUL 2

# %%
# Look at NAME counts for binning
counts1 = application_df['NAME'].value_counts()
counts1
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# HAVEN MINISTRIES INC                                  1
# MAUI CONSCIOUS DANCE COLLECTIVE                       1
# ALUMNI ASSOCIATION OF PASAY CITY ACADEMY              1
# CHRISTIANITY PURE & SIMPLE MINISTRIES                 1
# HORSESISTERS & ASSOCIATES INC                         1
# Name: NAME, Length: 19568, dtype: int64

# %%
# Choose a cutoff value and create a list of names_replace to be replaced
# use the variable name names_replace
names_replace = list(counts1[counts1<5].index)
names_replace
# Out:
# ['UNITED MINE WORKERS OF AMERICA- INTERNATIONAL',
#  'BACK COUNTRY HORSEMEN OF AMERICA',
#  'JEFFERSON CITY SENIOR HIGH SCHOOL PARENT TEACHERS ORGANIZATION',
#  'TEXAS WATER UTILITIES ASSOCIATION',
#  'SUNRISE 2000 INC',
#  'NATIONAL SORORITY OF PHI DELTA KAPPA INC',
#  'ALASKA PTA',
#  'KNIGHTS OF PETER CLAVER',
#  'AMATEUR ATHLETIC UNIONS OF THE US',
#  'THE UNITED STATE PONY CLUBS INC',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF LOUISIANA',
#  'NATIONAL SOCIETY OF THE CHILDREN OF THE AMERICAN REVOLUTION',
#  'TXCPSO INC',
#  'DEPARTMENT OF OREGON LADIES AUXILIARY TO THE VFW OF THE US',
#  'INSTITUTE OF ELECTRICAL AND ELECTRONICS ENGINEERS',
#  'GAMMA PHI BETA SORORITY INC',
#  'WESTERN GOVERNORS UNIVERSITY',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF OREGON',
#  'LOUISIANA 4-H FOUNDTION',
#  'STANDUP PARENTING INC',
#  'DELTA CHI NATIONAL HOUSING CORPORATION',
#  'SAFARI CLUB INTERNATIONAL FOUNDATION',
#  'SIGMA GAMMA RHO SORORITY INC',
#  'PARENTS FAMILIES AND FRIENDS OF LESBIANS AND GAYS INC',
#  'KIDS ENJOY EXERCISE NOW',
#  'INTERNATIONAL ASSOCIATION OF EATING DISORDERS PROFESSIONALS FOUNDATI',
#  'PTA NEW MEXICO CONGRESS',
#  'FREE & ACCEPTED MASONS OF LOUISIANA GRAND LODGE',
#  'PI KAPPA ALPHA FRATERNITY',
#  'PHI DELTA KAPP INTERNATIONAL INC',
#  'INTERNATIONAL ASSOCIATION OF ASSESSING OFFICERS',
#  'IDAHO CHAPLAINS CORPS INC',
#  'INDUSTRIAL WORKERS OF THE WORLD',
#  'INTELLIGENT TRANSPORTATION SOCIETY OF AMERICA ITS AMERICA',
#  'WOODMEN OF THE WORLD LIFE INSURANCE SOCIETY',
#  'ANCIENT FREE AND ACCEPTED MASONS OF OKLAHOMA',
#  'LIFE STEPS FOUNDATION INC',
#  'MUSIC TEACHERS NATIONAL ASSOCIATION',
#  'COMMEMORATIVE AIR FORCE',
#  'JUNIOR ROLLER DERBY ASSOCIATION',
#  'AMERICAN ORFF-SCHULWERK ASSOCIATION',
#  '4-H CLUBS & AFFILIATED 4-H ORGANIZATIONS',
#  'AMERICAN COACH ASSOCIATION',
#  'INTERNATIONAL READING ASSOCIATION INC',
#  'PTA IDAHO CONGRESS',
#  'EPSILON PI TAU INC',
#  'COMMUNICATION ALLIANCE TO NETWORK THOROUGHBRED EX-RACEHORSES',
#  'NATIONAL HOOK-UP OF BLACK WOMEN',
#  'VESTAVIA HILLS PARENT TEACHER ORGANIZATION INC',
#  'PILOT CLUB INTERNATIONAL',
#  'NATIONAL ASSOCIATION OF NEGRO BUSINESS AND PROFESSIONAL WOMENS C',
#  'SWEDISH WOMENS EDUCATIONAL ASSOCIATION',
#  'PUGET SOUND UNISERV COUNCIL',
#  'BAKERY CONFECTIONERY TOBACCO WORKERS AND GRAIN MILLERS INTL UNI',
#  'AMERICAN SOCIETY OF HEATING REFRIGERATING & A-C ENGINEERS',
#  'DEPARTMENT OF OKLAHOMA LADIES AUXILIARY TO THE VFW INC',
#  'TENNESSEE MUSIC EDUCATION ASSOCIATION',
#  'AMERICAN ROSE SOCIETY',
#  'UTILITY WORKERS UNION OF AMERICA AFL-CIO',
#  'BLUE STAR MOTHERS OF AMERICA INC',
#  'COMPUTER USING EDUCATORS',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF KANSAS',
#  'EXPERIMENTAL AIRCRAFT ASSOCIATION',
#  'OMEGA PSI PHI FRATERNITY',
#  'AMALGAMATED TRANSIT UNION',
#  'ORDER OF THE EASTERN STAR OF MISSOURI GRAND CHAPTER',
#  'METHODIST RETIREMENT COMMUNITIES',
#  'TEXAS STATE BRANCH 948 NATIONAL ASSOCIATION OF POSTAL SUPERVISORS',
#  'YOUNG CATHOLIC PROFESSIONALS',
#  'SOROPTIMIST INTERNATIONAL TO THE AMERICAS INC',
#  'AMATEUR ATHLETIC UNION OV THE UNITED STATES INC',
#  'TEXAS EXTENSION EDUCATION ASSOCIATION',
#  'FREE & ACCEPTED MASONS OF ALABAMA',
#  'BETA BETA BETA NATIONAL BIOLOGICAL HONOR SOCIETY',
#  'CLIPPED WINGS UNITED AIR LINES STEWARDESS ALUMNAE & FLIGHT ATTEND',
#  'UNITED FOOD AND COMMERCIAL WORKERS INTERNATIONAL UNION',
#  'PHI SIGMA KAPPA',
#  'AMERICAN AGAPE FOUNDATION INC',
#  'SOUTHERN EARLY CHILDHOOD ASSOC',
#  'UEMPOWERU INC',
#  'JOSHUA INC',
#  'ORDER OF EASTERN STAR PRINCE HALL AFFILIATION OF LOUISIANA',
#  'ANCIENT ORDER OF HIBERNIANS IN AMERICA',
#  'SUPREME TEMPLE PYTHIAN SISTERS',
#  'COLORADO COALITION FOR THE HOMELESS',
#  'FEDERALLY EMPLOYED WOMEN INC',
#  'UNITED BROTHERHOOD OF CARPENTERS & JOINERS OF AMERICA',
#  'WESTERN DRESSAGE ASSOCIATION OF AMERICA',
#  'SOCIETY FOR MAINTENANCE AND RELIABILITY PROFESSIONALS FND',
#  'ILLUMAN',
#  'GRAMBLING UNIVERSITY NATIONAL ALUMNI ASSOCIATION',
#  'GIRLS ON THE RUN INTERNATIONAL',
#  'PTA WASHINGTON CONGRESS',
#  'DERMATOLOGY NURSES ASSOCIATION',
#  'VERITY HEALTH SYSTEM OF CALIFORNIA INC',
#  'AMERICAN FISHERIES SOCIETY',
#  'SMOCKING ARTS GUILD OF AMERICA INC',
#  'ASSOCIATION OF PROPASAL MANAGEMENT PROFESSIONALS',
#  'ROYAL ARCH MASONS OF CALIFORNIA',
#  'SAFARI CLUB INTERNATIONAL',
#  'LIGHT FOR LIFE FOUNDATION INTERNATIONAL',
#  'LAMBDA CHI ALPHA FRATERNITY INC',
#  'REAL ESTATE STAGING ASSOCIATION INC',
#  'DAUGHTERS OF ISIS OF NORTH & SOUTH AMERICA',
#  'NATIONAL SOCIETY OF BLACK ENGINEERS',
#  'BMW CAR CLUB OF AMERICA INC',
#  'CFIRE CHRISTIAN FUNDAMENTALIST INTERNAL REVENUE EMPLOYEES',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF TENNESSEE',
#  'PHI DELTA KAPPA INTERNATIONAL INC',
#  'TEXAS ASSOCIATION OF SCHOOL BUINESS OFFICIALS',
#  'CALIFORNIA ASSOCIATION FOR NURSE PRACTITIONERS',
#  'NATIONAL ENGINEERS WEEK FOUNDATION',
#  'SERTOMA INTERNATIONAL SPONSORSHIP FUND',
#  'GREYHOUND PETS OF AMERICA',
#  'INSTITUTE OF REAL ESTATE MANAGEMENT OF THE NATL ASSN OF REALTORS',
#  'ORDER OF EASTERN STAR OF OKLAHOMA',
#  'AMERCIAN LEGION',
#  'AMERICAN MARKETING ASSOCIATION INC',
#  'UNITED STATES BOWLING CONGRESS',
#  'HILLEL THE FOUNDATION FOR JEWISH CAMPUS LIFE',
#  'PTA KANSAS CONGRESS OF PARENTS AND TEACHERS',
#  'GYRO INTERNATIONAL',
#  'CALIFORNIA PODIATRIC MEDICAL ASSOC',
#  'THE ARK OF TEXAS',
#  'FUTURE FARMERS OF AMERICA',
#  'ENTREPRENEURS ORGANIZATION',
#  'INTERNATIONAL SOCIETY OF AUTOMATION',
#  'HEALTH OCCUPATIONS STUDENTS OF AMERICA',
#  'CALIFORNIA PILOTS ASSOCIATION',
#  'CENTER FOR THE STUDY OF CLASSICAL ARCHITECTURE INC',
#  'THETA XI FRATERNITY',
#  'TEXAS SOCIETY OF PROFESSIONAL ENGINEERS',
#  'MINDS MATTER',
#  'ROYAL ARCH MASONS OF KANSAS',
#  'ALLIANCE OF DIVINE LOVE INC',
#  'PTA TENNESSEE CONGRESS OF PARENTS TEACHERS INC',
#  'NATIONAL FELLOWSHIP OF RACEWAY MINISTRIES',
#  'CORENET GLOBAL INC',
#  'ASSOCIATION OF SEWING AND DESIGN PROFESSIONALS INC',
#  'ASET-THE NEURODIAGNOSTIC SOCIETY',
#  'AMERICAN ASSOCIATION OF ZOO KEEPERS',
#  'ACADEMY OF MANAGED CARE PHARMACY',
#  'TRAUMA INTERVENTION PROGRAMS INC',
#  'OHIO STATE UNIVERSITY ALUMNI ASSOCIATION INC',
#  'WASHINTON STATE UNIVERSITY',
#  'NORTHWEST SWIM CIRCUIT',
#  'NATIONAL BLACK NURSES ASSOCIATION INC',
#  'ACADEMY OF GENERAL DENTISTRY',
#  'NATIONAL HUMAN RESOURCES ASSOCIATION INC',
#  'INTERNATIONAL UNION OF PAINTERS AND ALLIED TRADES',
#  'FLORIDA NATIVE PLANT SOCIETY INC',
#  'ORDER OF THE FOUNDERS & PATRIOTS OF AMERICA',
#  'NORTH AMERICAN FOLK MUSIC AND DANCE ALLIANCE INC',
#  'PACIFIC COAST NORWEGIAN SINGERS ASSOCIATION',
#  'PARAGON CHRISTIAN ALLIANCE INTERNATIONAL INC',
#  'FEDERATION OF TEXAS A&M UNIVERSITY MOTHERS CLUB',
#  'APPA ASSOCIATION OF HIGHER EDUCATION FACILITIES OFFICERS',
#  'VFW AUXILIARY DEPARTMENT OF MISSOURI',
#  'NORTH AMERICAN BUTTERFLY ASSOCIATION INC',
#  'PTA ARIZONA CONGRESS OF PARENTS AND TEACHERS INC',
#  'SOIL AND WATER CONSERVATION SOCIETY',
#  'FLORIDA EDUCATION ASSOCIATION',
#  'STOA',
#  'LAMBDA ALPHA INTERNATIONAL',
#  'OREGON HIGH SCHOOL RODEO ASSOCIATION INC',
#  'ALPHA KAPPA PSI FRATERNITY',
#  'UNIVERSITY OF FLORIDA NATIONAL ALUMNI ASSOCIATION INC',
#  'NATIONAL SPEAKERS ASSOCIATION',
#  'ALLIANCE FOR RETIRED AMERICANS',
#  'AMERICAN GROUP PSYCHOTHERAPY ASSOCIATION INC',
#  'ANCIENT FREE & ACCEPTED MASONS OF OREGON',
#  'WASHINGTON STATE UNIVERSITY 4-H CLUBS AND AFFILIATED 4-H ORGANIZAT',
#  'SIGMA THETA TAU INTERNATIONAL',
#  'TRUSTEES OF DARTMOUTH COLLEGE',
#  'HAMPTON UNIVERSITY',
#  'ALPHA GAMMA RHO FRATERNITY',
#  'NATIONAL SOCIETY UNITED STATES DAUGHTERS OF 1812',
#  'EARLY CHILDHOOD MUSIC ASSOCIATION',
#  'U M ARMY',
#  'AMERICAN COLLEGE OF PHYSICIANS SERVICES',
#  'SERTOMA FOUNDATION',
#  'HOLIDAY RAMBLER RECREATIONAL VEHICLE CLUB',
#  'AMERICAN RESEARCH CENTER IN EGYPT',
#  'STATE CHARTERED CREDIT UNIONS IN FLORIDA',
#  'AMERICAN CANCER SOCIETY INC',
#  'DAUGHTERS OF THE REPUBLIC OF TX INC',
#  'FULL GOSPEL ASSEMBLIES OF AMERICA INC',
#  'NATIONAL PONY EXPRESS ASSOCIATION',
#  'FLORIDA ASSOCIATION OF ENVIROMENTAL PROFESSIONALS INC',
#  'NATIONAL GERONTOLOGICAL NURSING ASSOCIATION INC',
#  'IZAAK WALTON LEAGUE OF AMERICA INC',
#  'AGENTS ASSOCIATION',
#  'HELPING YOUNG PEOPLE EXCEL INC',
#  'FRIENDS OF THE PARK',
#  'SEOUL NATIONAL UNIVERSITY ALUMNI',
#  'AMERICAN FEDERATION OF TEACHERS',
#  'OREGON STATE GRANGE PATRONS OF HUSBANDRY',
#  'ARC OF ARIZONA INC',
#  'SISTERS NETWORK',
#  'PRAISE CHAPEL CHRISTIAN FELLOWSHIP CHURCHES & MINISTRIES INTL',
#  'ASSOC FOR EDUCATION & REHBLTATN OF THE BLIND & VISUALLY IMPAIRED',
#  'PARENTS HELPING PARENTS INC',
#  'CHI EPSILON',
#  'NATIONAL UTILITY CONTRACTORS ASSOCIATION INC',
#  'PARENT BOOSTERS USA INC',
#  'LITTLE MISS KICKBALL INTERNATIONAL INC',
#  'IRON PIGS MOTORCYCLE CLUB',
#  'KAPPA BETA GAMMA INTERNATIONAL INC',
#  'COALITION OF LABOR UNION WOMEN CLUB',
#  'APPA-ASSOCIATION OF HIGHER EDUCATION FACILITIES OFFICERS',
#  'PEOPLE TO PEOPLE INTERNATIONAL',
#  'SIGMA CHI FRATERNITY',
#  'ASSOCIATION OF EVANGELICAL GOSPEL ASSEMBLIES',
#  'ROAL',
#  'BLACKS IN GOVERNMENT',
#  'WICHITA INDEPENDENT NEIGHBORHOODS INC',
#  'SERRA INTERNATIONAL',
#  'ORDER OF QUETZALCOATL PLUMED SERPENT',
#  'ORDER OF THE ALHAMBRA',
#  'TRANSPORT WORKERS UNION OF AMERICA',
#  'NATIONAL ALUMNAE ASSOC OF SPELMAN COLLEGE',
#  'ROYAL AND SELECT MASTERS OF GEORGIA',
#  'ASSOCIATION OF TRADITIONAL HOOKING ARTIST',
#  'WASHINGTON STATE UNIVERSITY 4-H CLUBS AND AFFILIATED ORGANIZATIONS',
#  'CONSTRUCTION FINANCIAL MANAGEMENT ASSOCIATION',
#  'TEXAS ASSOCIATION OF SCHOOL BUSINESS OFFICIALS',
#  'DANCE INITIATIVE INC',
#  'CORNERSTONE CHRISTIAN MINISTRIES',
#  'CONFRERIE DE-LA-CHAINE DES ROTISSEURS LTD',
#  'PARENTS WITHOUT PARTNERS INC',
#  'LOUISIANA GARDEN CLUB FEDERATION INC',
#  'TOOLBANK USA INC',
#  'AMERICAN HARP SOCIETY',
#  'TEXAS MASTER GARNENER ASSOCIATION INC',
#  'ASSOCIATION OF GOVERNMENT ACCOUNTANTS',
#  'KLEIN SUPPORT GROUP INC',
#  'STARS INC',
#  'SOCIETY OF FIRE PROTECTION ENGINEERS',
#  'HOLIDAY RAMBLER RECREATIONAL',
#  'PTA CALIFORNIA CONGRESS OF PARENTS TEACHERS AND STUDENTS INC',
#  'MILITARY ORDER OF THE COOTIE OF THE UNITED STATES',
#  'DELTA TAU DELTA FRATERNITY',
#  'KOREAN WAR VETERANS ASSOCIATION INC',
#  'WASHINGTON EXPLORER SEARCH AND RESCUE',
#  'ANCIENT EGYPTIAN ARABIC ORDER NOBLES MYSTIC SHRINE OF N & S AMER',
#  'RETROUVAILLE INTERNATIONAL INC',
#  'ZETA BETA TAU FRATERNITY',
#  'LABOR AND EMPLOYMENT RELATIONS ASSOCIATION',
#  'NATIONAL AMBUCS INC',
#  'IMPROVED ORDER OF RED MEN OF TEXAS',
#  'COMBAT VETERANS MOTORCYCLE ASSOCIATION',
#  'SOROPTIMIST INTERNATIONAL OF THE AMERICAS',
#  'ALPHA TAU OMEGA FRATERNITY',
#  'WOMEN MARINES ASSOCIATION',
#  'SIGMA GAMMA RHO SOROITY INC',
#  'UTAH EDUCATION ASSOCIATION',
#  'NATIONAL SOCIETY COLONIAL DAMES XVII CENTURY',
#  'NATIONAL AUTISM ASSOCIATION INC',
#  'NORTHERN PLAINS RESOURCE COUNCIL',
#  'JUMPSTART COALITION FOR PERSONAL FINANCIAL LITERACY',
#  'AMERICANS UNITED FOR SEPARATION OF CHURCH & STATE',
#  'CAMP QUEST INC',
#  'SOCIETY FOR HUMAN RESOURCE MANAGEMENT',
#  'CHARTER ROAD PRODUCTIONS INCORPORATED',
#  'SOCIETY FOR THE PRESERVATION AND ENCOURAGEMENT OF BARBERSHOP',
#  'FAR EASTERN UNIVERSITY NURSING ALUMNI FOUNDATION INC',
#  'HEALTHCARE INFORMATION AND MANAGEMENT SYSTEMS SOCIETY',
#  'M W PRINCE HALL GRAND LODGE FREE AND ACCEPTED MASONS OF LOUISIAN',
#  'INTERNATIONAL ALLIANCE THEATRICAL STAGE EMPLOYEES & MOVING PICTURE',
#  'LEAGUE OF WOMEN VOTERS OF FLORIDA',
#  'WOMEN IN AVIATION',
#  'ELDERLY HOUSING DEVELOPMENT AND OPERATIONS CORPORATION',
#  'ORDER OF THE AMARANTH INC SUPREME COUNCIL',
#  'SIGMA PI FRATERNITY INTERNATIONAL INC',
#  'MISSOURI INTERACTIVE TELECOMMUNICATIONS EDUCATION',
#  'INTERNATIONAL FEDERATION OF PROFESSIONAL & TECHNICAL ENGINEERS',
#  'KAPPA SIGMA FRATERNITY',
#  'VOITURE NATIONALE LA SOCIETE DES 40 HOMMES ET 8 CHEVAUX',
#  'FOLDS OF HONOR FOUNDATION',
#  'UNITED STATES PONY CLUB INC',
#  'SOCIETY OF CRITICAL CARE MEDICINE',
#  'AMERICAN RHODODENDRON SOCIETY',
#  'PILOT INTERNATIONAL INC',
#  'HOOSIER CARE INC',
#  'EXECUTIVE WOMENS GOLF ASSOCIATION',
#  'INTERNATIONAL ALLIANCE THEATRICAL STAGE EMPLOYEES',
#  'ASSOCIATION OF WOMEN IN THE METAL INDUSTRIES INC',
#  'BENEVOLENT & PROTECTIVE ORDER OF ELKS OF THE USA',
#  'CATHOLIC ENGAGED ENCOUNTER INC',
#  'PTA COLORADO CONGRESS',
#  'SERB NATIONAL FEDERATION',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF TEXAS',
#  'GRAND LODGE OF MISSISSIPPI FREE AND ACCEPTED MASONS',
#  'PEACEWORKS -- DANCES OF UNIVERSAL PEACE NORTH AMERICA',
#  'FREE & ACCEPTED MASONS OF MISSISSIPPI',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF NEW MEXICO OF THE U S',
#  'PHYSICIANS FOR SOCIAL RESPONSIBILITY INC',
#  'ASSOCIATION FOR CONFLICT RESOLUTION',
#  'CALIFORNIA STATE CARE PROVIDERS ASSOCIATION',
#  'FOUR LETTER WORD INC',
#  'NATIONAL COUNCIL OF THE UNITED STATES SOCIETY OF ST VNCNT DE PAUL',
#  'ACTIVE 20-30 UNITED STATES AND CANADA',
#  'SI ON',
#  'LINKS INC',
#  'AMERICAN ASSOCIATION OF FAMILY AND CONSUMER SCIENCES',
#  'PLANNED PARENTHOOD AFFILIATES OF CALIFORNIA INC',
#  'DEPRESSION AND BIPOLAR SUPPORT ALLIANCE',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF ARKANSAS',
#  'INTERNATIONAL CAPOEIRA ANGOLA FOUNDATION',
#  'CAMP FIRE',
#  'OASIS INSTITUTE',
#  'DAUGHTERS OF UNION VETERANS OF THE CIVIL WAR 1861 1865',
#  'HEARING LOSS ASSOCIATION OF AMERICA',
#  'INTERNATIONAL ASSOCIATION OF EATING DISORDERS PROFESSIONALS FOUNDATION',
#  'CALIFORNIA RETIRED TEACHERS ASSOCIATION',
#  'DAUGHTERS OF NORWAY',
#  'SOCIETY OF AMERICAN MILITARY ENGINEERS',
#  'HISPANIC DENTAL ASSOCIATION',
#  'UNITED COMMERCIAL TRAVELERS OF AMERICA',
#  'HOUSE OF HEROES INC',
#  'AMERICAN COLLEGE OF PHYSICIANS',
#  'KAPPA ALPHA PSI FRATERNITY INC',
#  'AMERICAN BUSINESS WOMENS ASSOCIATION',
#  'COUNCIL OF ALBUQUERQUE GARDEN CLUBS',
#  'LABORERS INTERNATIONAL UNION OF NORTH AMERICA',
#  'ALPHA DELTA KAPPA SORORITY INC',
#  'NATIONAL SOCIETY OF THE SONS OF UTAH PIONEERS',
#  'ANCIENT FREE & ACCEPTED MASONS OF COLORADO',
#  'THE ARC OF TEXAS',
#  'PTA LOUISIANA CONGRESS',
#  'NATIONAL JUNIOR COLLEGE ATHLETIC ASSOCIATION',
#  'REACT INTERNATIONAL',
#  'PTA MISSOURI CONGRESS',
#  'AMERICAN CRIMINAL JUSTICE ASSOCIATION LAMBDA ALPHA EPSILON',
#  'JOBS WITH JUSTICE EDUCATION FUND',
#  'VETERANS OF FOREIGN WARS AUXILIARY',
#  'INTERNATIONAL COSTUMERS GUILD INC',
#  'LAFAYETTE GARDEN CLUB',
#  'ETA PHI BETA SORORITY INC',
#  'AMERICAN TRAIN DISPATCHERS ASSOCIATION',
#  'NATIONAL ASSOCIATION OF POSTAL SUPERVISORS',
#  'NATIONAL DENTAL ASSOCIATION INC',
#  'AMERICAN ART THERAPY ASSOCIATION',
#  'MEA-MFT',
#  'POINT MAN INTERNATIONAL MINISTRIES',
#  'PAN AMERICAN ROUND TABLE OF TEXAS',
#  'FEDERATION OF FLY FISHERS',
#  'SOUTHEAST SECTION OF THE NINETY NINES INC',
#  'GRAND CHAPTER OF TENNESSEE ORDER OF THE EASTERN STAR',
#  'OMICRON KAPPA UPSILON-HONORARY DENTAL SOCIETY',
#  'UNITED SPINAL ASSOCIATION INC',
#  'SHERIFFS COMMUNITY ORGANIZED POLICING EFFORTS',
#  'IOTA PHI LAMBDA SORORITY INC',
#  'SAN RAMON VALLEY EDUCATIONAL FOUNDATION',
#  'DEPARTMENT OF NEVADA VETERANS OF FOREIGH WARS OF THE U S INC',
#  'IMMIGRANT HOPE',
#  'BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE USA',
#  'SAN BENITO YOUTH SOCCER LEAGUE',
#  'ASPENPOINTE INC',
#  'ALLIANCE OF THE FRIENDS OF THE DEKALB COUNTY LIBRARY',
#  'VFW AUXILIARY DEPARTMENT OF OKLAHOMA',
#  'NATIONAL ASSOCIATON OF CORPORATE DIRECTORS',
#  'BROTHERHOOD OF RAILROAD SIGNALMEN',
#  'UNITED TRANSPORTATION UNION',
#  'NATIONAL SOCIETY OF TOLE AND DECORATIVE PAINTERS INC',
#  'JOBS DAUGHTERS INTERNATIONAL',
#  'COMMUNITY NETWORK AFRICAN AMERICAN TELECOMMUNICATION PROFESSIONALS OF',
#  'AMERICAN HUMANIST ASSOCIATION',
#  'ANCHORAGE COMMUNITY MENTAL HEALTH SERVICES',
#  'MANKIND PROJECT',
#  'BIRTH NETWORK',
#  'GRAND LODGE OF MISSISSIPPI FREE & ACCEPTED MASONS',
#  'TRANSPORTATION ENERGY PARTNERSHIP',
#  'PTSA WASHINGTON CONGRESS',
#  'ROYAL ARCH MASONS OF TENNESSEE',
#  'ANCIENT FREE & ACCEPTED MASON OF KANSAS',
#  'AMERICAN LEGION POST',
#  'SIGMA THETA TAU INC',
#  'UNITED WORKERS',
#  'IDAHO ASSOCIATION FOR THE EDUCATION OF YOUNG CHILDREN',
#  'WEBSTER GROVES SCHOOL DISTRICT PARENT-TEACHERS ORGANIZATION',
#  'AMERICAN BEGONIA SOCIETY',
#  'SOUTHWEST DISTRICT KIWANIS FOUNDATION',
#  'VETERANS OF FOREIGH WARS OF THE UNITED STATES DEPT OF COLORADO',
#  'OMICRON KAPPA UPSILON HONORARY DENTAL SOCIETY',
#  'GARDENERS OF AMERICA INC',
#  'UNITED STATES MASTERS SWIMMING INC',
#  'YELLOWSTONE COUNTY 4-H COUNCIL',
#  'LEAGUE OF UNITED LATIN AMERICA CITIZENS',
#  'MULTI COMMUNITY DIVERSIFIED SERVICES INC',
#  'ECHO A SERVANTS HEART',
#  'UMPQUA ACTORS COMMUNITY THEATRE INC',
#  'TOLUCA LAKE LIONS CHARITY FOUNDATION',
#  'DOUGLAS COUNTY YOUTH ORCHESTRA',
#  'BRYANS CAUSE',
#  'PARENTS BOOSTER USA INC',
#  'MEDSTAR GLOBAL FOUNDATION',
#  'AMERICAN ASSOCIATION OF HEALTHCARE ADMINISTRATION MANAGEMENT',
#  'TRUE LIFE CHURCH- IGLESIA VIDA VERDADERA',
#  'AMERICAN ASSOCIATION OF PSYCHIATRIC TECHNICIANS',
#  'NEW JOURNEY MOVEMENT',
#  'PROJECT HEALING HEROES',
#  'VIKINGS DESERT MOTORCYCLE CLUB INC',
#  'SHARING HANDS A RESPITE EXPERIENCE INC',
#  'ARC OF WELD COUNTY',
#  'MOJAVE ENVIRONMENTAL EDUCATION CONSORTIUM',
#  'AVALON DRUID ORDER INC',
#  'ASSOCIATION FOR SYSTEMS MANAGEMENT OF TULSA',
#  'NOOKSACK VALLEY RIDERS ASSOCIATION',
#  'CALIFORNIA PODIATRIC MEDICAL ASSOCIATION',
#  'PARTNERS IN PARENTING',
#  'WOMENS FOUNDATION OF SOUTHWEST FLORIDA INC',
#  'GOOD SAMARITAN MINISTRY INC',
#  'CHRISTIAN LIFE MOVEMENT INC',
#  'CITY OF SACRAMENTO PIPE BAND INC',
#  'KLOROTECH FOUNDATION',
#  'ALL-STAR DANCE FOUNDATION INC',
#  'SEATTLE HORROR ORGANIZING COMMITTEE',
#  'ASK A SCIENTIST CORPORATION',
#  'AUSTIN FFA INC',
#  'LOVE DEMONSTRATED MINISTRIES INTERNATIONAL - EQUITY DEV SVCS',
#  'ROCKY MOUNTAIN REGIONAL CHAPTER OF THE SOCIETY OF ENVIRONMENTAL',
#  'MARGARET JOHNSON HILL SCHOLARSHIP',
#  'FLORIDAS FIRST COAST ASA INC',
#  'PIF',
#  'HOMEBIRTH CESAREAN INTERNATIONAL',
#  'WE THE PEOPLE-CULTURAL DANCE CENTER',
#  'COVENANT OF LOVE UUL CORP',
#  'MILES CITY YOUTH HOCKEY ASSOCIATION INC',
#  'CALIFORNIA ASSOCIATION OF AFRICAN AMERICAN SUPERINTENDENTS AND ADMIN',
#  'CONSORTIUM FOR THE ADVANCEMENT OF CHILDREN',
#  'BORSCHT CORP',
#  'FLICK RANCH PROJECT INC',
#  'ALAMO AREA ASSOCIATION OF SCHOOL',
#  'NATIONAL ASSOCIATION OF COMMUNITY AND RESTORATIVE JUSTICE',
#  'DELRAY COMMUNITY WELLNESS CENTER INC',
#  'DISBRO SCHOLARSHIP INC',
#  'SCHOLARS ACADEMY A VICTORIOUS EXPERIENCE',
#  'SERENITY RESIDENTIAL SERVICES INC',
#  'EASTERN WASHINGTON FAMILY DAYCARE ASSOCIATION',
#  'MM CONSERVATORY',
#  'ROGER JENNINGS DAVIS MEMORIAL FUND INC',
#  'SEEKERS CHURCH INC',
#  'PUGET SOUND YOUTH WIND ENSEMBLE-A NONPROFIT CORPORATION',
#  'CALL TO CARE INC',
#  'AIR FORCE VILLAGES INC',
#  'INTELLIGENT TRANSPORTATION SOCIETY OF CALIFORNIA',
#  'ADVOCACY RESOURCE CENTER INC',
#  'NECROTIZING ENTEROCOLITIS SOCIETY',
#  'PRESCOTT EVENING LIONS FOUNDATION',
#  'TRUST FOR BENEFIT OF GRUNDY COUNTY SCOUTS',
#  'OVERLAKE SERVICE LEAGUE',
#  'MIDDLE EAST TENNESSEE EMERGENCY RADIO SERVICE INC',
#  'EMERGENCY PEDIATRIC CARE ARIZONA EPC AZ',
#  'METAMORPHASIS POWERHOUSE COMPANY',
#  'RESOURCE ASSOCIATION FOR MISSING PEOPLE',
#  'JOHN B WINN PARENT TEACHER ASSOCIATION PTA AUSTIN TEXAS',
#  'FRIENDS OF FOSTER CHILDREN FOREVER INC',
#  'VOITURE LOCALE 35 LA SOCIETE DES 40 HOMMES ET 8 CHEV',
#  'FRIENDS REACHING INSPIRING & EDUCATING NEIGHBORS ABOUT DOWN SYN',
#  'SUPREME PYTHIAN SISTERS',
#  'ROBERT BRUCE PTC',
#  'LSCFSM INC',
#  'QUODLIBET INC',
#  'SISTERS OF THE SEA INC',
#  'OKLAHOMA LADIES FOR CHRISTIAN EDUCATION',
#  'HEALING ROOM OF KNOXVILLE- UPPER ROOM PRAYER MINISTRY',
#  'UNIFORMED SERVICES BENEFIT ASSOCIATION',
#  'LEAGUE OF WOMEN VOYERS OF METROPOLITAN PHOENIX',
#  'APOSTOLIC RESOURCE CENTER INCORPORATED',
#  'PRIDE THERAPEUTIC EQUESTRIAN CENTER',
#  'E-VAN MINISTRIES',
#  'NEW ORLEANS REGIONAL BLACK CHAMBER OF COMMERCE INC',
#  'SOUTHGATE ECUMENICAL RESOURCE CENTER',
#  'DREAM WEAVER CHARITABLE TR',
#  'PUEBLO COUNTY TEACHERS ASSOCIATION',
#  'DALLAS AREA REPRODUCTIVE ENDOCRINOLOGIST',
#  'EL CRESTON MUTUAL DOMESTIC WATER CONSUMERS ASSOCIATION',
#  'FRIENDS AT YOUR METRO ANIMAL SHELTER',
#  'NJOY ENTERPRISES',
#  'PROFESSIONAL CONSTRUCTION ESTIMATORS ASOC OF AMERICA INC',
#  'JUNIOR OPTIMIST BASEBALL LEAGUE',
#  'IM MODELING A NEW IMAGE',
#  'CENTRALIA ATHLETICS & ACTIVITIES FACILITIES FOUNDATION',
#  'STOPTUITIONHIKES - DOT - COM -- BACKSLASH -- FOUNDATION INC',
#  'SOUTH RIVER CITY CITIZENS INC',
#  'MINISTERIO DEL CRISTO REY DE LA RENOVACION CARISMATICA CATOLIC',
#  'PARENTS ASSOCIATION OF WOODBURN STUDENTS',
#  'TRICO',
#  'SHILOH-NEW HOPE COMMUNITY CEMETERY INC',
#  'A HUMANITARIAN ORGANIZATION PROMOTING EDUCATION',
#  'WILLIAMS FIRE ASSOCIATION',
#  'WAY OF REAL DISCOVERY',
#  'FEDERATION OF KOREAN CLEANERS ASSOCIATION INC',
#  'SIGSBEE CHARTER SCHOOL INC',
#  'KAREN COLLINS UN-TEAL THERE IS A CURE',
#  'HELPING ELEVATE LOW INCOME PEOPLE ECONOMIC AND COMMUNITY DEVELOPMEN',
#  'SHREE DURGA SHIVA VISHNU TEMPLE',
#  'ANTELOPE VALLEY HARLEY OWNERS GROUP',
#  'AF WINGMOMS',
#  'F I G L E A F EDUCATIONAL FESTIVALS',
#  'AQUAJAX INC',
#  'SOCIETY OF PEDIATRIC NURSES',
#  'POINT THE WAY FOUNDATION INC',
#  'COMMUNITY HEROES APPRECIATION MEMORIAL PROJECT',
#  'FORCED EXOTIC ANIMAL RELOCATION AND CENTER FOR EDUCATION INC',
#  'ROTARY VETERANS MEMORIAL PAVILIONINC',
#  'OAKLAND CENTER FOR EDUCATION & ECONOMIC DEVELOPMENT INC',
#  'MAUI RYUKYU CULTURE GROUP',
#  'WESTERN WASHINGTON AMATEUR TELEVISION SOCIETY',
#  'MUSEUM FOUNDATION OF PACIFIC GROVE INC',
#  'NATIONAL MINORITY BUSINESS ADVISORY COUNCIL',
#  'WAT DHAMMARARAM BUDDHIST ASSOCIATION INC',
#  'CHANGED PEOPLE TODAY INC',
#  'CRAFT COMMUNITY CARE CENTER INC',
#  'ALL OR NOTHIN',
#  'PARADISE OF THE PACIFIC CLUB MANAGERS ASSOC OF AMERICA',
#  'CALIFORNIA APPLICANTS ATTORNEYS ASSOCIATION WORKERS COMP ISSUES PA',
#  'UFCW VACATION TR',
#  'HARRINGTON PTA',
#  'LIVING IN FAITH AND EVOLVING MINISTRIES INC',
#  'HOME AWAY FROM HOME INC',
#  'GREATER NEW ORLEANS DRUM CORPS ASSOCIATION',
#  'CITYWATER MUSIC INC',
#  'HOPE FUND',
#  'CO ASCD',
#  'FRIENDS OF THE EAST ROSWELL LIBRARY',
#  'YELM INDEPENDENT FILM FOUNDATION',
#  'CARPENTER CEMETERY ASSOCIATION INC',
#  'AMBASSADOR WORLDWIDE HOLISTIC MINISTRIES ASSOCIATION',
#  'ALABAMA ASSOCIATION FOR PLAY THERAPY',
#  'TRENTS TOUCH INC',
#  'BEARFOOT RANCH INC',
#  'SOUTHERN CALIFORNIA PROFESSIONAL DEVELOPMENT SCHOOLS CONSORTIUM',
#  'LAKELAND REPEATER ASSOCIATION INCORPORATED',
#  'SALT & LIGHT',
#  'NATIONAL CLT NETWORK',
#  'MEDIA HOUSE INTERNATIONAL INC',
#  'SAN DIEGO ADVERTISING FUND FOR EMERGENCIES',
#  'USED TRUCK SALES NETWORK',
#  'PARK VALLEY FIRE DEPARTMENT',
#  'COUNCIL FOR TEACHING FILIPINO LANGUAGE AND CULTURE',
#  'BILL NICKLAS MEMORIAL JUNIOR GOLF FOUNDATION',
#  'NATIONAL INDIAN MONUMENT AND INSTITUTE INC',
#  'OSBOURNE COUNCIL NO 4759 KNIGHTS OF COLUMBUS',
#  'BOWEN ELEMENTARY PARENT-TEACHER ORGANIZATION',
#  'VINE RIPE KIDS OF CENTRAL FLORIDA INC',
#  'KACHIN DEVELOPMENT FOUNDATION USA INC',
#  'KID NET FOUNDATION',
#  'WAGGIN TAILS CANINE RESCUE',
#  'FOUNDATION FOR INSPIRATION & RECOGNITION SCIENCE & TECHNOLOGY I',
#  'LOUISIANA KIDS INC',
#  'AMIGOS UNIDOS INC',
#  'GREEN STREETS',
#  'ROB & SAM INC',
#  'PORT ARANSAS SWIM ASSOCIATION',
#  'TEXAS CAUCUS OF BLACK SCHOOL BOARD MEMBERS',
#  'STAR FOUNDATION OF COASTAL GEORGIA INC',
#  'CANONSBURG CORPORATION',
#  'HARMONY IN HOOVES INC',
#  'FAMILY VIOLENCE INTERVENTION PROGRAM INC',
#  'STRUNC INC',
#  'COUNTRY DAY SCHOOL HEADMASTERS',
#  'DRUG ALCOHOL AND TOBACCO EDUCATION',
#  'NORTHERN CA RVERS',
#  'MBRAVES BASEBALL CLUB INC',
#  'WOMAN AT THE WELL TRANSITION CENTER',
#  'EL NATHAN MINISTRIES INC',
#  'HELPING OUT PEOPLE EVERYWHERE INC',
#  'RICHMOND STEELERS YOUTH FOOTBALL AND CHEER A NEW GENERATION INC',
#  'TENNESSEE DEAF-BLIND ASSOCIATION',
#  'BANGLADESH ASSOCIATION OF GREATER AUSTIN',
#  'LADIES HOME FELLOWSHIP MINISTRIES INC',
#  'HOME IMPROVEMENT SEMINARS INC',
#  'JUDIAN SOCIETY',
#  'BLUE CURE FOUNDATION',
#  'TRINBAGO ASSOCIATION OF CENTRAL FLORIDA INC',
#  'CSEA RETIRED DIVISION INC',
#  'INTERNATIONAL ASSOCIATION OF HOSPITALITY ACCOUNTANTS 10-15-1998',
#  'FREESTYLE FITNESS 29 LLC',
#  'SISTERS UNITED FOR PROSPERITY AND ADVANCEMENT',
#  'HUMANITARIAN AID RELIEF FUND',
#  'FOUNDATION OF KNIGHTS OF THE CARMEL MISSION INC',
#  'CHURCH ON WHEELS INC',
#  'MINISTRY OF FAITH CHRISTIAN CENTER INC',
#  'ASSOCIATED GENERAL CONTRACTORS HEALTH BENEFIT TR AK WA CHAPTERS',
#  'SOUTHERN UNIVERSITY ALUMNI FEDERATION',
#  'COOLANU INC',
#  'LONE STAR BLACK BELT ACADEMY PARENTS ASSOCIATION',
#  'AUGUSTA JEWISH MUSEUM INC',
#  'PHILOSOPHY LEARNING AND TEACHING ORGANIZATION',
#  'NGUYEN THAI HOC FOUNDATION',
#  'GEORGIA TACTICAL OFFICERS ASSOCIATION INC',
#  'GRAND COULEE DAM POST 157',
#  'HALOALAUNUIAKEA EARLY LEARNING CENTER',
#  'CAPITAL AIRSHOW GROUP',
#  'T-N-T BOXING CLUB',
#  'ASSOCIATION OF HISPANIC MUNICIPAL OFFICIALS',
#  'KALIKOLEHUA - EL SISTEMA HAWAII',
#  'SAVE OUR SIBERIANS-SIBERSPACE RESCUE FUND',
#  'TEXAS VOLUNTARY ORGANIZATIONS ACTIVE IN DISASTER',
#  'TRUMAN MEDICAL CENTER PROFESSIONAL AND GENERAL LIABILITY SELF-INS TR',
#  'EASTERN MISSOURI BEEKEEPERS ASSN',
#  'VISUAL ARTS GUILD BOOKER T WASHINGTON HIGH SCHOOL FOR THE',
#  'THE WOODEN FLOOR FOR YOUTH MOVEMENT',
#  'TALL TAILS RESCUE BAIL BONDSMEN FOR DOGS INC',
#  'CHELSEA BASEBALL CLUB INC',
#  'EARL E & ELMYRA SUSIE J EULER WATHENA HIGH SCHOOL SCHOLARSHIP TR',
#  'IMPACT 360 INSTITUTE INC',
#  'STORM ASSIST LLC',
#  'ASSOCIATION OF VETERINARY HEMATOLOGY AND TRANSFUSION MEDICIN',
#  'ACHIEVEMENT REWARDS FOR COLLEGE SCIENTISTS FOUNDATION INC OREGON',
#  'TREASURE VALLEY CHRISTIAN NEWS INC',
#  'CHAN NGUYEN MEDITATION CENTER INC',
#  'WILLIE DAVIS MINISTRIES INC',
#  'OPENACC-STANDARD ORG',
#  'E B SCRIPPS ELEMENTARY SCHOOL ACADEMIC FUNDRAISING PARTNERSHIP',
#  'FRIENDS OF MID-SOUTH ANIMAL SHELTERS INC',
#  'THE ENCOURAGEMENT HOUSE',
#  'DENVER BIKE SHARING',
#  'PROJECT WAKE UP',
#  'KITTY CAUSE CAT RESCUE',
#  'KANSAS CITY CHAPTER OF THE NATIONAL BLACK MBA ASSOCIATION INC',
#  'LUBBOCK AREA LIGHTS ABWA',
#  'GIFTS OF GREEN FOUNDATION INC',
#  'TORCHBEARERS-HIS HILL',
#  'CEDAR SPRINGS PARENT TEACHER ORGANIZATION',
#  'PHI BETA SIGMA FRATERNITY INC',
#  'COASTAL EMPIRE MONTESSORI ACADEMY INCORPORATED',
#  'LIFEMESSAGE INTERNATIONAL INC',
#  'ALASKA MOVING IMAGES PRESERVATION ASSOCIATION',
#  'ALLIANCE FOR TECHNOLOGY EDUCATION IN ADVANCED MATH AND SCIENCE CORP',
#  'FRIENDS AND VOLUNTEERS',
#  'PAUL J MCGRADY SR FOUNDATION INC',
#  'HOMETOWN PENINSULA INDEPENDENT BUSINESS ALLIANCE',
#  'MIND RESEARCH INSTITUTE',
#  'FULL GOSPEL BUSINESS MENS FELLOWSHIP IN AMERICA CUMMING CHAP',
#  'ACADEMIC EDGE FOR GIRLS IN SPORTS FOUNDATION',
#  'SMOKY CREEK RANCH RELIGIOUS TRUST',
#  'NATALIA VOLUNTEER FIRE DEPARTMENT INC',
#  'LITTLETON JAZZ FOUNDATION',
#  'UNITED STATES-CHINA EXCHANGE COUNCIL',
#  'KENNEY-WEST FUND LTD',
#  'HELPING EVERYONE RECOVER COLORADO',
#  'BRINGING BACK THE BOW CORP',
#  'DANCE DOWNTOWN LA INC',
#  'HEART 4 HEART',
#  'CHARLIE AND JANE BAYLESS SCHOLARSHIP FUND',
#  'THE UNITY AND HOPE CENTER',
#  'CCAP',
#  'STOP-STUDENTS THAT OFFICIALLY PATROL',
#  'TEAM TOOTLES FOUNDATION',
#  'SIERRA GREEN BUILDING ASSOCIATION',
#  'JAPANESE EDUCATION EXCHANGE FUND INC',
#  'THE SIG R YOUNG CHAPTER',
#  'LUBBOCK HIGH SCHOOL SOFTBALL BOOSTER CLUB',
#  'CAREER ACADEMY FOR INTERNATIONAL CULTURE & COMMERCE BOOSTER CLUB IN',
#  'ARIZONA APPRAISERS WHO CARE',
#  'STEEL HOPE',
#  'BIG BEAR LAKE VILLAGE BUSINESS ASSOCIATION',
#  'NORTH CASCADE WASHINGTON CHAPTER OF HARLEY OWNERS GROUP',
#  'TORRANCE AIR FAIR ASSOCIATION',
#  'SEATTLE BASKETBALL YOUTH ASSOCIATION',
#  'OKLAHOMA CLIMBING TEAM ASSOCIATION',
#  'MONTANA ASSOCIATION OF CHEIFS OF POLICE',
#  'OLD ANACORTES ROWING SOCIETY',
#  'WESTSIDE FAMILY HEALTH CENTER',
#  'P A WALSH HOME & SCHOOL CLUB',
#  'PLUMAS AUDUBON SOCIETY',
#  'NATIONAL ASSOCIATION OF ASIANAMERICAN PROFESSIONALS - PHOENIX IN',
#  'SLEEP ADVOCATES OF MISSOURI',
#  'MAT SU SERTOMA CLUB',
#  'FETAL ALCOHOL SYNDROME CONSULTATION EDUCATION AND TRAINING SERVICES IN',
#  'TRADITIONAL JAZZ SOCIETY OF AUSTIN',
#  'ROTARY CLUB OF APPLE VALLEY FOUNDATION',
#  'SECOND CHANCE AT LUCID EMANCIPATED SERENITY',
#  'MID MISSOURI LAW ENFORCEMENT FIREFIGHTERS & EMS FUND',
#  'FAMILY FIRST',
#  'HEALING TOUCH HEALING HEARTS TRAMBLE MCKINNON HOMES INC',
#  'FRIENDS OF FRUITLAND',
#  'RHO CHAPTER OF THE SOCIETY OF PHI ZETA',
#  'CARTHAGE KIWANIS CLUB',
#  'WILLIAM PAUL HATFIELD SCHOLARSHIP TRUST',
#  'EDUCATION CITIES INC',
#  'LUMINA PE STRADA MINISTRIES',
#  'CITY OF COMPASSION COMMUNITY DEVELOPMENT CORPORATION',
#  'WYLIE ANIMAL RESCUE FOUNDATION',
#  'CENTRAL LOUISIANA EDUCATION AND YOUTH DEVELOPMENT',
#  'AFRICAN POLICY AND APPLIED RESEARCH INSTITUTE',
#  'CHILDRENS CORPORATION',
#  'SHELBY COUNTY SCHOLASTIC CLAY TARGET ASSOCIATION',
#  'NEIL ARMSTRONG ACADEMIC BOOSTERS',
#  'SUNGARD PUBLIC SECTOR USERS GROUP ASSOCIATION',
#  'SATCHEL PAIGE FOUNDATION',
#  'NORTH AMERICAN BABYDOLL SOUTHDOWN SHEEP ASSOCIATION AND REGISTRY',
#  'LITTLE STAR FOUNDATION',
#  'MISSISSIPPI GULF COAST GEM & MINERAL SOCIETY INC',
#  'INGLEWOOD PMA INC',
#  'AMERICAN BAPTIST HOMES OF WASHINGTON',
#  'SUNSHINE LEARNING GROUP INC',
#  'CHRISTOPHER XAVIER DICKERSON FOUNDATION',
#  'HOMESCHOOL ORGANIZATION FOR PREPARATORY EDUCATION',
#  'HEELING HEELERS HEART DOG RESCUE',
#  'EZ KIDS CREATIVITY SHELL',
#  'INTERNATIONAL ASSOCIATION OF WILDLAND FIRE',
#  'MWI VETERINARY SUPPLY INC GROUP INSURANCE FUND',
#  'TRIBUTE TO THE TROOPS',
#  'TAMPA DOWNTOWN LIONS FOUNDATION INC',
#  'ACADIANA GOOD TIMES ROLLERS',
#  'MOUNTAIN ACOUSTIC MUSIC ASSOCIATION',
#  'ALABAMA URBAN AND REGIONAL INFORMATION SYSTEMS ASSOCIATION',
#  'LATIN BUSINESS NETWORK',
#  'JES COMMUNITY DEVELOPMENT CORPORATION',
#  'OIC OF BROWARD COUNTY INC',
#  'RESIDENTS UNITED FOR PLANNING AND ACTION INC',
#  'MANCHACA ONION CREEK HISTORICAL ASSN',
#  'CENTRAL ALABAMA BEST INC',
#  'TOUCH INDIA MINISTERIES INC',
#  'BIKECDA INC',
#  'END HT NOW INC',
#  'APE CONSERVATION EFFORT INC',
#  'MEACHAM PARK NEIGHBORHOOD IMPROVEMENT ASSOCIATION',
#  'AVON PARK PROFESSIONAL FIREFIGHTERS LOCAL 3132',
#  '116TH CAVALRY REGIMENT CHAPTER OF THE US CAVALRY & ARMOR ASSOCIATION',
#  'WASHINGTON ASSOCIATION OF CODE ENFORCEMENT',
#  'IRVING INTERNATIONAL WOMENS CONSORTIUM',
#  'TRINITY UNIVERSITY',
#  'ABC OF SOUTHERN CALIFORNIA BENEFIT TRUST FUND',
#  'PLANT YOUR DREAMS PRODUCTIONS INC A CALIFORNIA PUBLIC BENEFIT CORP',
#  'ARTS ACADEMY INC',
#  'INTERNATIONAL GATEWAY HOUSE FOR BOYS INCORPORATED',
#  'LARIAT LOOP HERITAGE ALLIANCE',
#  'VOICES FOR UMOJA INC',
#  'WOMEN IN COMMERICAL REAL ESTATE INC',
#  'INTERNATIONAL FRIEND ASSIST FOUNDA',
#  'IATSE LOCAL 16 TRAINING TRUST FUND',
#  'COMMUNITY GROWTH ALLIANCE INC',
#  'MT VERNON VOLUNTEER FIRE DEPARTMENT',
#  'POPLAR GROVE HELPING OTHER PEOPLE ENDURE',
#  'RED RIVER SPCA',
#  'IKAROS CHAPTER PANCRETAN ASSOCIATION OF AMERICA',
#  'DREAMCENTER INC',
#  'INTERNATIONAL TRAINING IN COMMUNICATION',
#  'ARTHUR & RUTH TAYLOR IRRV TRUST FBO 0902304700',
#  'MATAGORDA LIONS CLUB',
#  'CRUSE MEDICAL CARE INC',
#  'FEDERATION OF BANGLADESHI ASSOCIATIONS IN NORTH AMERICA',
#  'EAST UNION RURITAN CLUB',
#  'TODAY LAND CONSERVATION TRUST',
#  'THE VERO BEACH LIONS CLUB INC',
#  'COMBAT MARINE OUTDOORS INC',
#  'CHELAN COUNTY FIRE DISTRICT 9 AUXILIARY',
#  'KNIGHTSEN PARENT TEACHER CLUB',
#  'NATIONAL DEFENSE TRANSPORATION ASSO CATION',
#  'INDIANTOWN HISTORICAL SOCIETY INC',
#  'EDUCATIONAL CORPORATION MUKOGAWA GAKUIN',
#  'CONGRESSIONAL AWARD FOUNDATION',
#  'NORTH CALIFORNIA ASSOCIATION OF FRIENDS FROM TAY NINH',
#  'H E A R T OF CHULA VISTA ANIMAL CARE FACILITY',
#  'RIO GRANDE VALLEY-FAMILIES & FRIENDS OF MURDERED CHILDREN INC',
#  'APPLEGATE VALLEY COMMUNITY NEWSPAPER',
#  'UTSALADY BOOSTER CLUB',
#  'SMALL BUSINESS SYNERGY CORPORATION',
#  'DEFENDERS OF AMERICANS VOICE IN DECISION-MAKING',
#  'LIVING IN WELLNESS CENTER INC',
#  'CLBA',
#  'MAGDALENA MINISTRIES INC',
#  'AID TO ABUSED WOMEN',
#  'EMBRACE YOUR CAPE NON PROFIT',
#  'HELPING ASSISTING NURTURING THE DEVELOPMENTALLY DELAYED',
#  'MANY RIVERS ORDER OF INTERBEING SANGHA',
#  'EAGLE LAKE FOUNDATION INC',
#  'CC MASON ELEMENTARY PARENT TEACHER ORGANIZATION',
#  'NATIONAL ASSOC OF CONST CONTRACTORS COOPERATIVE INC',
#  'BRICKLAYERS LOCAL NO 3 VACATION AND HOLIDAY FUND',
#  'CALLAHAN COUNTY AGING SERVICES',
#  'JONES RD COMMUNITY LLC',
#  'SOLID ROCK FOUNDATION MINISTRIES',
#  'TIMBERLINE BASSET HOUND CLUB',
#  'SINGLE PARENT SCHOLARSHIP FUND OF CRAWFORD FRANKLIN AND SEBASTIAN',
#  'PROJECT CHILDHELP INC',
#  'NATIONAL ASSOCIATION TO BROADEN AND ENHANCE IMAGES INC',
#  'FONTANA INTERNATIONAL SOCCER ACADEMY',
#  'SUFFICIENCY OF FAMILIES',
#  'BY FAITH MINISTRIES',
#  'THE NATIONAL SORORITY OF PHI DELTA KAPPA INC GAMMA THETA',
#  'TRIMBLE CEMETARY ASSOCIATION',
#  'IMPERIAL COURT OF ALL OKLAHOMA',
#  'ROBINSON RANCH',
#  'FAMILY INVOLVEMENT CENTER',
#  'GRACE UNITED INTERNATIONAL INC',
#  'CALIFORNIA ELDER MENTAL HEALTH AND AGING COALITION',
#  'THE SPAY AND NEUTER INTERCOMMUNITY PROJECT TEAM INC',
#  'OREGON 57 ORDER OF EASTERN STAR',
#  'CHOLLAS LAKE PARKS AND RECREATION COUNCIL',
#  'TRACK & FIELD OFFICIALS ASSOCIATION OF ALASKA',
#  'AGAPE CHILDRENS EMERGENCY SHELTER HOUSTON',
#  'JUDY HOUSE MINISTRY INC',
#  'ALYBOO & IZYBEE FOUNDATION INC',
#  'CITIZENS ORGANIZING FOR RESOURCESAND ENVIRONMENT',
#  'SOUTHWEST WASHINGTON SHRM',
#  'HAWAII BEACH VOLLEYBALL ASSOCIATION',
#  'KNIGHTS OF COLUMBUS BASILICA OF ST MICHAEL THE ARCHANGEL COUNCIL 8589',
#  'SOUTH FLORIDA DENTAL HYGIENE ASSOCIATION INC',
#  'TRANSCEND FOUNDATION',
#  'REFORMED UNIVERSITY OF U S A',
#  'INTERNATIONAL ASSOCIATION OF BROADCAST MONITORS',
#  'USA ANIRIDIA NETWORK',
#  'SACRAMENTO MUNICIPAL UTILITY EMPLOYEES ASSOCIATION',
#  'ASSOCIATED STUDENTS UCLA',
#  'SNF MIR LODGE 85',
#  'FALL-LINE ALLIANCE FOR A CLEAN ENVIRONMENT',
#  'EMPOWERING SUCCESSFUL TEENS THROUGH EDUCATION AWARENESS & MENTORING',
#  'CHRIST FELLOWSHIP CHRUCH OF BEAUMONT',
#  'MANGOMUNDO FOUNDATION INC',
#  'AREA COMMUNITIES ENRICHMENT FOUNDATION',
#  'CRESCENT HARBOR PTA 8 7 6',
#  'DECATUR BULLDOG ATHLETIC BOOSTER CLUB',
#  'INDIA DISCIPLESHIP NETWORK',
#  'EAGLE SPRINGS ELEMENTARY PARENT TEACHER ORGANIZATION',
#  'DALLAS COUNTY DISTRICT ATTORNEY COMMUNITY AMBASSADORS',
#  'EAST HOLLYWOOD HIGH SCHOOL INC',
#  'INTERNATIONAL PEACE INSTITUTE',
#  'DRUID CITY DERBY',
#  'BAY AREA COMMUNITY DEVELOPMENT CORPORATION INC',
#  'PEACE RIVER CORVETTE CLUB INC',
#  'FANARI-ACADEMY OF GREEK EDUCATION INC',
#  'RESOURCE CENTER',
#  'SUSTAINABLE ACTION FUND FOR THE ENVIRONMENT',
#  'IDAHO VOICES FOR DIVERSITY INC',
#  'COLORADO COMMUNICATIONS FOUNDATION',
#  'WYOMING WAVES',
#  'INTERGOVERNMENTAL MANAGEMENT TRAINING PROGRAM',
#  'YIGONGYI CENTER FOR NONPROFITS',
#  'HANNA MINISTRIES-PROJECT JERICHO',
#  'ROTARY YOUTH EXCHANGE FLORIDA INC',
#  'RED ROCKS CENTURY INC',
#  'ASIAN PACIFIC INTERNAL REVENUE EMPLOYEES',
#  'SAFER ALTERNATIVE FOR ENJOYABLE RECREATION',
#  'THE VIETNAMESE ASSOCIATION OF PHYSICIANS DENTISTS AND',
#  'CEDARS CULTURAL AND EDUCATIONAL FOUNDATION',
#  'MARY BRANCH PARENT-TEACHER ORGANIZATION OF BRYAN',
#  'ARCADIA PLACE INC',
#  'A MILLION MATTERS INC',
#  'MOOREHOUSE FAMILY & COMMUNITY SERVICES',
#  'MOUNT HOOD CHAPTER OF CREDIT UNIONS',
#  'PROTAC FOUNDATION INC',
#  'UNITED COMMUNITY OUTREACH',
#  'MIKE FORCE ASSOCIATION INC',
#  'HAVING A NEW DEVELOPMENT',
#  'NORTHEAST TENNESSEE SPORTS ASSOCIATION INC',
#  'TAKSHILA EDUCATION INC',
#  'NEPALIS AND FRIENDS ASSOCIATION',
#  'LOS ALAMOS JUVENNILE JUSTICE ADVISORY BOARD INC',
#  'TENNESSEE ACADEMY OF SCIENCE',
#  'BUSINESS PROFESSOR INC',
#  'PREVENTION EDUCATION PROGRAMS INC',
#  'RAYTOWN TOUCHDOWN CLUB CO',
#  'MEMORIAL HOSPITAL-WEST VOLUSIA INC',
#  'WBE OF PUGET SOUND',
#  'COMMISSION ON COLLEGIATEINTERPRETER EDUCATION',
#  'NEVADA BRAIN BEE ASSOCIATION',
#  'BELLEVUE HIGHLINE SNO-KING KENDO CLUB',
#  'BISCAYNE BAY WATERKEEPER INC',
#  'FLORIDA ASSOCIATION OF GOVERNMENTAL FLEET ADMINISTRATORS',
#  'HUMAN & EQUAL RIGHTS ORGANIZERS',
#  'TENNESSEE ORTHOPAEDIC FOUNDATION FOR EDUCATION AND RESEARCH TOFER',
#  'FLORIDA THOROUGHBRED RETIREMENT AND ADOPTION CARE PROGRAM',
#  'TRAINING AND RESEARCH INSTITUTE FOR PROFESSIONAL LAW ENFORCEMENT',
#  'LADIES ANCIENT ORDER OF HIBERNIANS OF CALIFORNIA STATE',
#  'D SCOTT HUGHES CENTER FOR COUNSELING AND REHABILITATION',
#  'FRIENDS OF THE WEBER-MORGAN CHILDRENS JUSTICE CENTER',
#  'PROFIT & LOSS ASSOCIATION OF SWLA INC',
#  'CARRIERS OF THE CONSCIOUSNESS OF WHOLENESS INC',
#  'SMYRNA RHF HOUSING INC',
#  'KOREAN RESIDENT CLUB',
#  'PROMISE ASSEMBLY 41 INTERNATIONAL ORDER OF THE RAINBOW FOR GIRLS',
#  'GENESIS PAROCHIAL SCHOOLS',
#  'STEIN ELEMENTARY PARENT TEACHER ORGANIZATION',
#  'LAUREL SPRINGS WOMENS GOLF ASSOCIATION',
#  'BIDERMANS PRACTICES OF SUCCESS',
#  'NORTHWEST SENIOR HOUSING CORPORATION',
#  'FOUNDATION FOR THE LEAST LAST & LOST OF VISALIA INC',
#  'COMMUNITY OUTREACH',
#  'ANGELS ON EARTH MINISTRIES',
#  'SUTTON SENIOR ANNEX INC',
#  'THE FLORIDA RESTAURANT & LODGING ASSOCIATION INC',
#  'KIDS EDUCATIONAL & MENTAL HEALTH NETWORK INC',
#  'LOCAL 2809 WORKERS UNITED AW SEIU',
#  'STAY DIVERSE INC',
#  'YUMA AMATEUR RADIO CLUB',
#  'RETIREE MEDICAL AND LIFE INSURANCE TRUST FOR ROGERS STATE UNIVERSITY',
#  'PENINSULA DISTANCE CLUB',
#  'DUPLICATE BRIDGE OF AMARILLO INC',
#  'COMMUNITY ALCOHOL DRUG AFTERCARE PROGRAM',
#  'VALLEY COMMUNITY FOR RECYCLING SOLUTIONS',
#  'BE OUTDOORS ARIZONA FOUNDATION',
#  'GIRLS LEADING OUR WORLD INCORPORATED',
#  'SECOND CHANCE AT LOVE FOR DOGS',
#  'JASON LEE PTA',
#  'COURT APPOINTED SPECIAL ADVOCATES OF MESA COUNTY',
#  'ACCESS CONNECTIONS TO SUCCESS INC',
#  'MEREA MINISTRY INC',
#  'RIVERS OF JUDAH MINISTRIES INC',
#  'REACH REGISTRY INC',
#  'RIO GRANDE VALLEY AREA HEALTH EDUCATION CENTER',
#  'NATIONAL ASSOCIATION OF NEONATAL NURSES',
#  'MADISON-TALLULAH EDUCATION CENTER',
#  'COMMUNITY PARTNERS',
#  'PURPLE READER PROJECT INC',
#  'DISABLED AMERICAN VETERANS AUXILIARY INC BAY PINES HOLIDAY IS',
#  'FANT MINISTRIES INC',
#  'DIRT CONCERN',
#  'WENTWORTH FOUNDATION INC',
#  'INSTITUTE OF THE ROCKIES',
#  'PARTNERS IN LITERACY',
#  'WHEN ARE WE GOING HOME MINISTRY',
#  'UNITED STATES VETERANS ARTISTS ALLIANCE',
#  'PROTECTORS OF COMPANION ANIMALS INC',
#  'CALIFORNIA VIRTUAL ACADEMY AT KINGS',
#  'ALABAMENSE CHAPTER OF THE AZELEA SO CIETY OF AMERICA INCORPORATED',
#  'EPSILON OMEGA SIGMA CHAPTER OF SIGMA GAMMA RHO SORORITY',
#  'ST PAULS ORTHODOX CHURCH DALLAS',
#  'S & T HEALTH CONSULTING GROUP',
#  'JAMESTOWN HARLEY OWNERS GROUP CHAPTER 8102 A CA MUTUAL BENEFIT C',
#  'UTAH WOMENS FOOTBALL',
#  'TAYLOR HAUGEN FOUNDATION INC',
#  'BAYHORSE FOUNDATION TR',
#  'HEARTHFIRE ENTERPRISES INC',
#  'RUNNING WITH SOLE INC',
#  'REACH OUT AMERICA A NON PROFIT TR 010193',
#  'DEVELOPMENTAL RECREATIONAL ART WORKSHOPS',
#  'SCOTT NEWTON SMITH MINISTRIES INC',
#  'POLLINATOR CORRIDORS INC',
#  'MEMPHIS PETS ALIVE',
#  'GOODWILL OF NORTH GEORGIA INC',
#  'SECOND WARD FUTBOL CLUB',
#  'TRADITIONAL ART OF TAE KWON DO INSTITUTE INC',
#  'ART TRANSFORMS INC',
#  'CHAPPLE HILL CAT SERVICES',
#  'PULSE PRODUCTIONS',
#  'OAES PTO',
#  'OLATHE SOUTH BAND BOOSTERS',
#  'SRI RANGA RAMANUJA MAHA DESIKAN FINE ARTS',
#  'RURAL COMMUNITY HOSUING DEVELOPMENT CORPORATION',
#  'PHOENIX SUNFISH SWIM CLUB INC',
#  'HEAVEN EMPOWERED - COMMUNITY ASSISTANCE NETWORK',
#  'WOMEN SUPPORTING WOMEN ASSOCIATION INC',
#  'NORTHWEST SCHOOL FOR HEARING IMPAIRED CHILDREN',
#  'SHERWOOD MIDDLE SCHOOL PARENT ADVISORY COUNCIL',
#  'ELITE 2002 LADIES SOCCER INCORPORATED',
#  'DR JOBS MISSION TO THE PERSECUTED CHURCH',
#  'RED RIVER RACING TEAM',
#  'JEG MINISTRIES',
#  'VISHAV GURMAT ROOHANI MISSION CHARITABLE TRUST',
#  'ERIC ANDERSON MEMORIAL FOUNDATION INC',
#  'C R T A DIVISION 86 SCHOLARSHIP COMMITTEE',
#  'OUR SISTERS PROJECT',
#  'FRIENDS INTERESTED IN DOGS & OPEN SPACE INC',
#  'TREE OF LIFE',
#  'DENVER WORLD AFFAIRS COUNCIL',
#  'MISS BELLFLOWER COMPETITION',
#  'IGLESIA CRISTIANA DIOS ES NUESTRO AMPARO Y FORTALEZA',
#  'PARENTS ACTION FOR CHILDREN',
#  'REGIONAL STATE CENTER ADVISORY COUNCIL',
#  'BREAKTHROUGH COMMUNITY ENRICHMENT',
#  'BUSINESS IMPROVEMENT DISTRICT FOUNDATION',
#  'LS & S PRESCHOOL',
#  'UNDERWATER BAR ASSOCIATION',
#  '42 SAMAJ OF GREATER KANSAS CITY INC',
#  'TAMARACK MOUNTAIN SPORTS EDUCATION TEAM INC',
#  'BOOKS FOR TROOPS TAMPA BAY INC',
#  'BLACK WOMEN IN BUSINESS',
#  'BERKELEY YOUTH LIVING WITH DISABILITES',
#  'VIBE INC',
#  'GOODLAND AMBASSADORS INC',
#  'CBU CARES INC',
#  'NORTHWEST AREA CHILDBIRTH EDUCATORS FORUM NACEF',
#  'FLYING HOUSE PRODUCTIONS',
#  'FRIENDS OF SHIPLEY NATURE CENTER',
#  'JACK YATES CLASS OF 1968 ALUMNI',
#  'PARENT-TEACHERS ORGANIZATION OF CASTLE ROCK',
#  'PIKES PEAK ARTEMIS',
#  'BLANCHE K WERNER PUBLIC LIBRARY TRUST FUND',
#  'SEVEN OAK PTA 4 4 29',
#  'FOUNDATION FOR THE CONTROL AND PREVENTION OF INFECTIOUS DISEASE',
#  'KNIGHTS OF THE YORK CROSS OF HONOUR CONVENT GENERAL',
#  'ARIZONA YOUTH BALLET MESA',
#  'TOUCH ME NOT INC',
#  'GREAT FALLS CONVENTION AND VISITORS BUREAU',
#  'PROPHETIC ROAR PRODUCTION',
#  'SADDLEBROOKE TROOP SUPPORT',
#  'NATIONAL CHARITY LEAGUE INC COLORADO BLUE SKY CHAPTER',
#  'SAVVY CYBER KIDS INCORPORATED',
#  'STUDENT BODY OF AMERICA ASSOCIATION',
#  'PULASKI COUNTY 4-H CLUB FOUNDATION INC',
#  'STEEL HORSE SISTERHOOD INC',
#  'SERVE OUR DOG AREAS SODA',
#  'NORTHWEST ENVIRONMENTAL AND SELF RELIANCE TRUST',
#  'TEXOMA EMMAUS COMMUNITY INC',
#  ...]

# %%
# Replace in dataframe
for name in names_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                                                19803
# PARENT BOOSTER USA INC                                                1260
# TOPS CLUB INC                                                          765
# UNITED STATES BOWLING CONGRESS INC                                     700
# WASHINGTON STATE UNIVERSITY                                            492
#                                                                      ...
# INTERNATIONAL WOMENS INSOLVENCY & RESTRUCTURING CONFEDERATION INC        5
# JAMESTOWN SOCIETY                                                        5
# HERITAGE ACADEMY INC                                                     5
# CHC COMMUNITY CARE LLC                                                   5
# LEAGUE OF UNITED LATIN AMERICAN CITIZENS                                 5
# Name: NAME, Length: 403, dtype: int64

# %%
# Look at APPLICATION TYPE counts for binning
counts = application_df['APPLICATION_TYPE'].value_counts()
counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(counts[counts<500].index)
application_types_to_replace
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T15', 'T29', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
countsbinning = application_df['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
countsclassification = countsbinning[countsbinning>1]
countsclassification
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1237        9
# C1235        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C0           3
# C2710        3
# C1260        3
# C1246        2
# C1234        2
# C1267        2
# C1256        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list (countsbinning[countsbinning<100].index)
classifications_to_replace
# Out:
# ['C2800',
#  'C7100',
#  'C1300',
#  'C1280',
#  'C1230',
#  'C1400',
#  'C7200',
#  'C2300',
#  'C1240',
#  'C8000',
#  'C7120',
#  'C1500',
#  'C6000',
#  'C1800',
#  'C1250',
#  'C8200',
#  'C1278',
#  'C1238',
#  'C1237',
#  'C1235',
#  'C7210',
#  'C2400',
#  'C1720',
#  'C4100',
#  'C1257',
#  'C1600',
#  'C0',
#  'C2710',
#  'C1260',
#  'C1246',
#  'C1234',
#  'C1267',
#  'C1256',
#  'C3200',
#  'C1580',
#  'C2150',
#  'C4120',
#  'C2561',
#  'C2500',
#  'C2170',
#  'C2570',
#  'C1900',
#  'C8210',
#  'C2600',
#  'C1248',
#  'C4200',
#  'C1236',
#  'C3700',
#  'C5200',
#  'C1732',
#  'C2380',
#  'C1570',
#  'C1370',
#  'C1728',
#  'C1820',
#  'C6100',
#  'C1283',
#  'C1245',
#  'C4500',
#  'C2190']

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df,dtype=float)
application_df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                       1.0                       0.0
# 1       1   108590  ...                       1.0                       0.0
# 2       1     5000  ...                       1.0                       0.0
# 3       1     6692  ...                       1.0                       0.0
# 4       1   142590  ...                       1.0                       0.0
#
# [5 rows x 453 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
y
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
# drop 'IS SUCCESSFUL'
X = application_df.drop('IS_SUCCESSFUL', axis=1).values
X
# Out:
# array([[1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.0859000e+05, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        ...,
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 3.6500179e+07, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00]])

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=7
hidden_nodes_layer2=14
hidden_nodes_layer3=21
nn = tf.keras.models.Sequential()

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 7)                 3171
#
#  dense_1 (Dense)             (None, 14)                112
#
#  dense_2 (Dense)             (None, 1)                 15
#
# =================================================================
# Total params: 3,298
# Trainable params: 3,298
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,validation_split=0.15, epochs=100)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5541 - accuracy: 0.7282 - val_loss: 0.4647 - val_accuracy: 0.7826
# Epoch 2/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4559 - accuracy: 0.7763 - val_loss: 0.4457 - val_accuracy: 0.7875
# Epoch 3/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4423 - accuracy: 0.7842 - val_loss: 0.4421 - val_accuracy: 0.7880
# Epoch 4/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4371 - accuracy: 0.7858 - val_loss: 0.4372 - val_accuracy: 0.7901
# Epoch 5/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4336 - accuracy: 0.7865 - val_loss: 0.4362 - val_accuracy: 0.7917
# Epoch 6/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4322 - accuracy: 0.7897 - val_loss: 0.4379 - val_accuracy: 0.7898
# Epoch 7/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4311 - accuracy: 0.7907 - val_loss: 0.4355 - val_accuracy: 0.7932
# Epoch 8/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4300 - accuracy: 0.7917 - val_loss: 0.4363 - val_accuracy: 0.7930
# Epoch 9/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4291 - accuracy: 0.7919 - val_loss: 0.4384 - val_accuracy: 0.7953
# Epoch 10/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4284 - accuracy: 0.7931 - val_loss: 0.4382 - val_accuracy: 0.7906
# Epoch 11/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4278 - accuracy: 0.7921 - val_loss: 0.4386 - val_accuracy: 0.7948
# Epoch 12/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4275 - accuracy: 0.7921 - val_loss: 0.4401 - val_accuracy: 0.7935
# Epoch 13/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4273 - accuracy: 0.7933 - val_loss: 0.4374 - val_accuracy: 0.7961
# Epoch 14/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4271 - accuracy: 0.7918 - val_loss: 0.4384 - val_accuracy: 0.7940
# Epoch 15/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4263 - accuracy: 0.7931 - val_loss: 0.4402 - val_accuracy: 0.7896
# Epoch 16/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4260 - accuracy: 0.7921 - val_loss: 0.4395 - val_accuracy: 0.7930
# Epoch 17/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4254 - accuracy: 0.7939 - val_loss: 0.4378 - val_accuracy: 0.7940
# Epoch 18/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4254 - accuracy: 0.7937 - val_loss: 0.4382 - val_accuracy: 0.7948
# Epoch 19/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4248 - accuracy: 0.7937 - val_loss: 0.4399 - val_accuracy: 0.7968
# Epoch 20/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4246 - accuracy: 0.7958 - val_loss: 0.4399 - val_accuracy: 0.7976
# Epoch 21/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4246 - accuracy: 0.7947 - val_loss: 0.4402 - val_accuracy: 0.7966
# Epoch 22/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4239 - accuracy: 0.7956 - val_loss: 0.4403 - val_accuracy: 0.7987
# Epoch 23/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4238 - accuracy: 0.7959 - val_loss: 0.4392 - val_accuracy: 0.7974
# Epoch 24/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.7969 - val_loss: 0.4387 - val_accuracy: 0.7999
# Epoch 25/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4228 - accuracy: 0.7964 - val_loss: 0.4395 - val_accuracy: 0.8002
# Epoch 26/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4224 - accuracy: 0.7970 - val_loss: 0.4407 - val_accuracy: 0.7981
# Epoch 27/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4222 - accuracy: 0.7957 - val_loss: 0.4400 - val_accuracy: 0.7997
# Epoch 28/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4221 - accuracy: 0.7977 - val_loss: 0.4397 - val_accuracy: 0.8007
# Epoch 29/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4214 - accuracy: 0.7977 - val_loss: 0.4387 - val_accuracy: 0.7989
# Epoch 30/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4205 - accuracy: 0.7985 - val_loss: 0.4426 - val_accuracy: 0.7987
# Epoch 31/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4205 - accuracy: 0.7991 - val_loss: 0.4386 - val_accuracy: 0.8010
# Epoch 32/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4206 - accuracy: 0.7984 - val_loss: 0.4395 - val_accuracy: 0.7984
# Epoch 33/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4202 - accuracy: 0.7995 - val_loss: 0.4419 - val_accuracy: 0.7958
# Epoch 34/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4196 - accuracy: 0.7980 - val_loss: 0.4425 - val_accuracy: 0.7994
# Epoch 35/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4196 - accuracy: 0.7989 - val_loss: 0.4391 - val_accuracy: 0.7976
# Epoch 36/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4194 - accuracy: 0.7995 - val_loss: 0.4397 - val_accuracy: 0.8007
# Epoch 37/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.7979 - val_loss: 0.4395 - val_accuracy: 0.8020
# Epoch 38/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4189 - accuracy: 0.7988 - val_loss: 0.4391 - val_accuracy: 0.7987
# Epoch 39/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4186 - accuracy: 0.7998 - val_loss: 0.4396 - val_accuracy: 0.7999
# Epoch 40/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4184 - accuracy: 0.7998 - val_loss: 0.4408 - val_accuracy: 0.7961
# Epoch 41/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4183 - accuracy: 0.7989 - val_loss: 0.4416 - val_accuracy: 0.7989
# Epoch 42/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4185 - accuracy: 0.7999 - val_loss: 0.4397 - val_accuracy: 0.7992
# Epoch 43/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4181 - accuracy: 0.8004 - val_loss: 0.4400 - val_accuracy: 0.7945
# Epoch 44/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4179 - accuracy: 0.8000 - val_loss: 0.4401 - val_accuracy: 0.7984
# Epoch 45/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4177 - accuracy: 0.8004 - val_loss: 0.4409 - val_accuracy: 0.7987
# Epoch 46/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4171 - accuracy: 0.8006 - val_loss: 0.4417 - val_accuracy: 0.7955
# Epoch 47/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4172 - accuracy: 0.8005 - val_loss: 0.4403 - val_accuracy: 0.7999
# Epoch 48/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4173 - accuracy: 0.7997 - val_loss: 0.4402 - val_accuracy: 0.7984
# Epoch 49/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4166 - accuracy: 0.8006 - val_loss: 0.4387 - val_accuracy: 0.7987
# Epoch 50/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4168 - accuracy: 0.8000 - val_loss: 0.4426 - val_accuracy: 0.7945
# Epoch 51/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4168 - accuracy: 0.8005 - val_loss: 0.4401 - val_accuracy: 0.7992
# Epoch 52/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4164 - accuracy: 0.8016 - val_loss: 0.4389 - val_accuracy: 0.7997
# Epoch 53/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4160 - accuracy: 0.8005 - val_loss: 0.4422 - val_accuracy: 0.7971
# Epoch 54/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4156 - accuracy: 0.8023 - val_loss: 0.4410 - val_accuracy: 0.7987
# Epoch 55/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4150 - accuracy: 0.8015 - val_loss: 0.4388 - val_accuracy: 0.8020
# Epoch 56/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4149 - accuracy: 0.8023 - val_loss: 0.4402 - val_accuracy: 0.7999
# Epoch 57/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4150 - accuracy: 0.8016 - val_loss: 0.4400 - val_accuracy: 0.8012
# Epoch 58/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4146 - accuracy: 0.8024 - val_loss: 0.4389 - val_accuracy: 0.8028
# Epoch 59/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4145 - accuracy: 0.8022 - val_loss: 0.4418 - val_accuracy: 0.8007
# Epoch 60/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4142 - accuracy: 0.8030 - val_loss: 0.4402 - val_accuracy: 0.8015
# Epoch 61/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4139 - accuracy: 0.8007 - val_loss: 0.4399 - val_accuracy: 0.8046
# Epoch 62/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4133 - accuracy: 0.8025 - val_loss: 0.4415 - val_accuracy: 0.8028
# Epoch 63/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4139 - accuracy: 0.8023 - val_loss: 0.4417 - val_accuracy: 0.8033
# Epoch 64/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4140 - accuracy: 0.8018 - val_loss: 0.4414 - val_accuracy: 0.8012
# Epoch 65/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4141 - accuracy: 0.8018 - val_loss: 0.4408 - val_accuracy: 0.8010
# Epoch 66/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4135 - accuracy: 0.8026 - val_loss: 0.4421 - val_accuracy: 0.8018
# Epoch 67/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4135 - accuracy: 0.8027 - val_loss: 0.4427 - val_accuracy: 0.8010
# Epoch 68/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4129 - accuracy: 0.8026 - val_loss: 0.4418 - val_accuracy: 0.7999
# Epoch 69/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4128 - accuracy: 0.8024 - val_loss: 0.4434 - val_accuracy: 0.8025
# Epoch 70/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4128 - accuracy: 0.8023 - val_loss: 0.4463 - val_accuracy: 0.8020
# Epoch 71/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4127 - accuracy: 0.8025 - val_loss: 0.4453 - val_accuracy: 0.8005
# Epoch 72/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4125 - accuracy: 0.8029 - val_loss: 0.4456 - val_accuracy: 0.7997
# Epoch 73/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4125 - accuracy: 0.8032 - val_loss: 0.4470 - val_accuracy: 0.7963
# Epoch 74/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4120 - accuracy: 0.8028 - val_loss: 0.4453 - val_accuracy: 0.8002
# Epoch 75/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4119 - accuracy: 0.8033 - val_loss: 0.4450 - val_accuracy: 0.8028
# Epoch 76/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4122 - accuracy: 0.8022 - val_loss: 0.4455 - val_accuracy: 0.7999
# Epoch 77/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8024 - val_loss: 0.4471 - val_accuracy: 0.8020
# Epoch 78/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4116 - accuracy: 0.8036 - val_loss: 0.4465 - val_accuracy: 0.8002
# Epoch 79/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4116 - accuracy: 0.8041 - val_loss: 0.4445 - val_accuracy: 0.8031
# Epoch 80/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4118 - accuracy: 0.8037 - val_loss: 0.4452 - val_accuracy: 0.8015
# Epoch 81/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8040 - val_loss: 0.4465 - val_accuracy: 0.8015
# Epoch 82/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8044 - val_loss: 0.4462 - val_accuracy: 0.8028
# Epoch 83/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4105 - accuracy: 0.8040 - val_loss: 0.4473 - val_accuracy: 0.8018
# Epoch 84/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4112 - accuracy: 0.8044 - val_loss: 0.4471 - val_accuracy: 0.8018
# Epoch 85/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8040 - val_loss: 0.4476 - val_accuracy: 0.8015
# Epoch 86/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8037 - val_loss: 0.4488 - val_accuracy: 0.8033
# Epoch 87/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8032 - val_loss: 0.4463 - val_accuracy: 0.8002
# Epoch 88/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4104 - accuracy: 0.8022 - val_loss: 0.4476 - val_accuracy: 0.8028
# Epoch 89/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4103 - accuracy: 0.8043 - val_loss: 0.4476 - val_accuracy: 0.8033
# Epoch 90/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4100 - accuracy: 0.8041 - val_loss: 0.4474 - val_accuracy: 0.8038
# Epoch 91/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8036 - val_loss: 0.4484 - val_accuracy: 0.8012
# Epoch 92/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4096 - accuracy: 0.8040 - val_loss: 0.4484 - val_accuracy: 0.7999
# Epoch 93/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4095 - accuracy: 0.8043 - val_loss: 0.4472 - val_accuracy: 0.8031
# Epoch 94/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4090 - accuracy: 0.8045 - val_loss: 0.4463 - val_accuracy: 0.8028
# Epoch 95/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4092 - accuracy: 0.8053 - val_loss: 0.4457 - val_accuracy: 0.8018
# Epoch 96/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4086 - accuracy: 0.8047 - val_loss: 0.4445 - val_accuracy: 0.8059
# Epoch 97/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4089 - accuracy: 0.8053 - val_loss: 0.4473 - val_accuracy: 0.8031
# Epoch 98/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.4085 - accuracy: 0.8043 - val_loss: 0.4460 - val_accuracy: 0.8062
# Epoch 99/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4084 - accuracy: 0.8045 - val_loss: 0.4468 - val_accuracy: 0.8041
# Epoch 100/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4083 - accuracy: 0.8044 - val_loss: 0.4464 - val_accuracy: 0.8028

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.4647 - accuracy: 0.7869 - 229ms/epoch - 856us/step
# Loss: 0.4646620452404022, Accuracy: 0.7869387865066528

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('/content/AlphabetSoupCharity_Optimization.h5')
files.download('/content/AlphabetSoupCharity_Optimization.h5')
